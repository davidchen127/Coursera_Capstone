# %% [markdown]
# Capston Project assignment: Segmenting and Clustering Neighborhoods in Toronto

# %%
#!pip install bs4
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
url='https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto'
html_data=requests.get(url).text
soup=BeautifulSoup(html_data,'html5lib')
tables = soup.find_all('table')
for index,table in enumerate(tables):
    if ("Neighbourhoods covered" in str(table)):
        table_index = index
print(table_index)
print(tables[table_index].prettify())
# Out:
# mmons/thumb/8/8a/Mountdennis_to_locator.gif/100px-Mountdennis_to_locator.gif" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Mountdennis_to_locator.gif/150px-Mountdennis_to_locator.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Mountdennis_to_locator.gif/200px-Mountdennis_to_locator.gif 2x" width="100"/>
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td>
#     Mount Olive-Silverstone-Jamestown
#    </td>
#    <td>
#     Etobicoke
#    </td>
#    <td>
#     <a href="/wiki/Smithfield,_Toronto" title="Smithfield, Toronto">
#      Smithfield
#     </a>
#    </td>
#    <td>
#     <a class="image" href="/wiki/File:Mountolivesilverstonejamestown_to_locator.gif">
# ...

# %%
Toronto_neighborhoods = pd.DataFrame(columns=["PostalCode", "Borough", "Neighborhood"])
for row in tables[table_index].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        postcode = col[0].text.strip()
        borough = col[1].text.strip()
        neighborhood = col[3].text.strip()
        Toronto_neighborhoods = Toronto_neighborhoods.append({"PostalCode":postcode, "Borough":borough, "Neighborhood":neighborhood}, ignore_index=True)
Toronto_neighborhoods['PostalCode']=pd.to_numeric(Toronto_neighborhoods['PostalCode'])
Toronto_neighborhoods.sort_values('PostalCode',inplace=True)
Toronto_neighborhoods.reset_index(drop=True)
# Out:
#      PostalCode                            Borough          Neighborhood
# 0             1             West Humber-Clairville
# 1             2  Mount Olive-Silverstone-Jamestown            Smithfield
# 2             3       Thistletown-Beaumond Heights
# 3             4                    Rexdale-Kipling               Rexdale
# 4             5                   Elms-Old Rexdale  The Elms and Rexdale
# ..          ...                                ...                   ...
# 135         136                          West Hill
# 136         137                             Woburn
# 137         138                      Eglinton East         Eglinton East
# 138         139                Scarborough Village
# 139         140                          Guildwood             Guildwood
#
# [140 rows x 3 columns]
